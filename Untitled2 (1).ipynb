# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent (f, learning_rate, initial_point):
    def deriv(f, base_point):
        return (f(base_point + 1e-5)- f(base_point))/1e-5

    x_coords=[initial_point]
    y_coords=[f(initial_point)]
   
    for _ in range(10000):
        gradient = deriv(f, x_coords[-1])
        update = -learning_rate * gradient
        x_coords.append(x_coords[-1] + update)
        y_coords.append(f(x_coords[-1]))

    plot_range = np.linspace(min(x_coords) - 0.5, max(x_coords) + 0.5, 10000)
    function_range = [f(i) for i in plot_range]
    plt.plot(plot_range, function_range)
    plt.plot(x_coords, y_coords, marker= '0', color= 'r')
    plt.xlabel('X')
    plt.ylabel('f(X)')
    plt.title('Gradient Descent Optimization')
    plt.show()

    return round(x_coords[-1], 3), round(y_coords[-1], 3)

def f(x):
    if x>0:
        return x**x
    elif x==0:
        return 1
    else:
        return abs(x)**abs(x)

learning_rate = 0.1
initial_point = -1.0

result = gradient_descent (f, learning_rate, initial_point)
print("Local Minima:", result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/matplotlib/markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/_api/__init__.py:168, in check_shape(_shape, **kwargs)
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ValueError: 'vertices' must be 2D with shape (M, 2). Your input has shape ().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 39
#      36 learning_rate = 0.1
#      37 initial_point = -1.0
# ---> 39 result = gradient_descent (f, learning_rate, initial_point)
#      40 print("Local Minima:", result)
#
# Cell In[14], line 20, in gradient_descent(f, learning_rate, initial_point)
#      18 function_range = [f(i) for i in plot_range]
#      19 plt.plot(plot_range, function_range)
# ---> 20 plt.plot(x_coords, y_coords, marker= '0', color= 'r')
#      21 plt.xlabel('X')
#      22 plt.ylabel('f(X)')
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:544, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:544, in <listcomp>(.0)
#     542     return list(result)
#     543 else:
# --> 544     return [l[0] for l in result]
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:537, in <genexpr>(.0)
#     534 else:
#     535     labels = [label] * n_datasets
# --> 537 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     538                       {**kwargs, 'label': label})
#     539           for j, label in enumerate(labels))
#     541 if return_kwargs:
#     542     return list(result)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/lines.py:368, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     366     marker = 'none'  # Default.
#     367 if not isinstance(marker, MarkerStyle):
# --> 368     self._marker = MarkerStyle(marker, fillstyle)
#     369 else:
#     370     self._marker = marker
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/markers.py:362, in MarkerStyle._set_marker(self, marker)
#     360         self._marker_function = self._set_vertices
#     361     except ValueError as err:
# --> 362         raise ValueError('Unrecognized marker style {!r}'
#     363                          .format(marker)) from err
#     365 if not isinstance(marker, MarkerStyle):
#     366     self._marker = marker
#
# ValueError: Unrecognized marker style '0'
